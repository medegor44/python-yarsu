# %% [markdown]
# # Работа с базами данных в Python

# %% [markdown]
# ## DB API
# DB API это стандартизированный набор методов для работы с базами данных в Python.
#
# ![db-api](dbapi.png)

# %% [markdown]
# Предварительная подготовка:
# 1. Запустить БД, если она еще не запущена. Будем использовать mssql в docker `docker run -e "ACCEPT_EULA=Y" -e "MSSQL_SA_PASSWORD=1234qwE?" -e "MSSQL_PID=Express" -p 1433:1433 -d mcr.microsoft.com/mssql/server:2022-latest`
# 2. Установить драйвер для mssql `uv add mssql-python`
# 3. Научимся подключаться из приложений для работы с бд (dbeaver, datagrip и тп)
# 4. Создать тестовую базу данных и наполнить ее данными

# %%
# !docker run -e "ACCEPT_EULA=Y" -e "MSSQL_SA_PASSWORD=1234qwE?" -e "MSSQL_PID=Express" -p 1433:1433 -d mcr.microsoft.com/mssql/server:2022-latest

# %%
# !uv add mssql-python
# !pip install mssql-python
# Out:
# Resolved 47 packages in 15ms
# Audited 45 packages in 9ms

# %% [markdown]
# # Установка соединения

# %%
# Просто подключимся к БД

import mssql_python
connection_string = 'SERVER=localhost;PORT=1433;DATABASE=todo;UID=sa;PWD=1234qwE?;Encrypt=no'
conn = mssql_python.connect(connection_string)
cur = conn.cursor()

# TODO

cur.close()
conn.close()

# %%
# Просто подключимся к БД

import mssql_python
connection_string = 'SERVER=localhost;PORT=1433;DATABASE=todo;UID=sa;PWD=1234qwE?;Encrypt=no'
# Для Windows
# connection_string = 'SERVER=.;DATABASE=todo;Authentication=ActiveDirectoryIntegrated;Encrypt=no'
with mssql_python.connect(connection_string) as conn:
    with conn.cursor() as cur:
        pass
        # TODO

# %% [markdown]
# ## Что тут происходит
# 1. Создали connection string
# 2. Открыли подключение, передав строку в `connect`
# 3. Создали курсор - объект для работы с БД
# 4. Затем, так как подключение и курсор это внешние по отношению к питону ресурсы мы должны их освободить с помощью методов `close`
#
# ## Как устроен connection string
# Строка это набор элементов `<key>=<value>` описывающая то как надо подключаться к БД
#
# |key|Описание|
# |:--|:-------|
# |Server|Адрес подключения к бд|
# |Port|Порт подключения к бд|
# |Database|Имя самой базы данных|
# |UID|Имя пользователя|
# |PWD|Пароль пользователя|
# |Encrypt|Включение/выключение шифрования отправляемых данных|
# |Authentication|Способ аутентификации пользователя|
#
# Кроме этих полей есть еще несколько других о которых можно прочитать в [документации](https://github.com/microsoft/mssql-python/wiki/Connection-to-SQL-Database#connection-string) к драйверу.

# %% [markdown]
# # Чтение данных из БД

# %%
# Читаем из БД

with mssql_python.connect(connection_string) as conn:
    with conn.cursor() as cur:
        cur.execute("select * from items")

        print(cur.fetchall())
# Out:
# [('buy milk', False), ('do homework', True), ('read book', True), ('play games', False)]

# %% [markdown]
# Выгружать из базы все не всегда удобно (хотя курсор все равно выгржает все данные в память), поэтому иногда имеет смысл читать ответ построчно

# %%
# Читаем из БД построчно
with mssql_python.connect(connection_string) as conn:
    with conn.cursor() as cur:
        cur.execute("select * from items where done=1")
        
        print(cur.fetchone())
        print(cur.fetchone())
        print(cur.fetchone())
        print(cur.fetchone())
        print(cur.fetchone())
        print(cur.fetchone())
# Out:
# ('do homework', True)
# ('read book', True)
# None
# None
# None
# None

# %%
# Курсор как итератор
with mssql_python.connect(connection_string) as conn:
    with conn.cursor() as cur:
        cur.execute("select * from items where done=1")
        
        for row in cur:
            print(row)
# Out:
# ('do homework', True)
# ('read book', True)

# %% [markdown]
# # Запись данных в БД

# %%
# Сперва пишем, а потом читаем
with mssql_python.connect(connection_string) as conn:
    with conn.cursor() as cur:
        cur.execute("insert into items values('watch movie', 0)")
        cur.commit() # сохраняем данные в таблицу
        cur.execute("select * from items")
        for row in cur:
            print(row)
# Out:
# ('buy milk', False)
# ('do homework', True)
# ('read book', True)
# ('play games', False)
# ('watch movie', False)
# ('watch movie', False)

# %%
with mssql_python.connect(connection_string) as conn:
    with conn.cursor() as cur:
        cur.execute("select * from items")
        for row in cur:
            print(row)
# Out:
# ('buy milk', False)
# ('do homework', True)
# ('read book', True)
# ('play games', False)
# ('watch movie', False)
# ('watch movie', False)

# %% [markdown]
# Часто бывает необходимо выполнять параметризованные запросы: пользователь передает в вашу функцию название айтема и флаг выполнен ли он, а вы должны вставить. Ваши предложения, как это можно сделать?

# %%
def insert_item(cur: mssql_python.Cursor, name: str, done: bool):
    cur.execute(f"insert into items values ('{name}', {1 if done else 0})")


with mssql_python.connect(connection_string) as conn:
    with conn.cursor() as cur:
        # sql injection!!!
        # insert_item(cur, "xxx', 1); drop table items; --", True)
        cur.commit() # сохраняем данные в таблицу
        cur.execute("select * from items")
        for row in cur:
            print(row)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[21], line 8
#       6 insert_item(cur, "xxx', 1); drop table items; --", True)
#       7 cur.commit() # сохраняем данные в таблицу
# ----> 8 cur.execute("select * from items")
#       9 for row in cur:
#      10     print(row)
#
# File ~/Projects/python-yarsu/lesson5/.venv/lib/python3.13/site-packages/mssql_python/cursor.py:982, in Cursor.execute(self, operation, use_prepare, reset_cursor, *parameters)
#     978 # Check return code
#     979 try:
#     980
#     981 # Check for errors but don't raise exceptions for info/warning messages
# --> 982     check_error(ddbc_sql_const.SQL_HANDLE_STMT.value, self.hstmt, ret)
#     983 except Exception as e:
#     984     log('warning', "Execute failed, resetting cursor: %s", e)
#
# File ~/Projects/python-yarsu/lesson5/.venv/lib/python3.13/site-packages/mssql_python/helpers.py:78, in check_error(handle_type, handle, ret)
#      76 if logger:
#      77     logger.error("Error: %s", error_info.ddbcErrorMsg)
# ---> 78 raise_exception(error_info.sqlState, error_info.ddbcErrorMsg)
#
# File ~/Projects/python-yarsu/lesson5/.venv/lib/python3.13/site-packages/mssql_python/exceptions.py:651, in raise_exception(sqlstate, ddbc_error)
#     649     if logger:
#     650         logger.error(exception_class)
# --> 651     raise exception_class
#     652 raise DatabaseError(
#     653     driver_error=f"An error occurred with SQLSTATE code: {sqlstate}",
#     654     ddbc_error=f"{ddbc_error}" if ddbc_error else f"Unknown DDBC error",
#     655 )
#
# ProgrammingError: Driver Error: Base table or view not found; DDBC Error: [Microsoft][SQL Server]Invalid object name 'items'.

# %%
# Передача параметризованных запросов: именованные и не именованные параметры

def insert_item_named_args(cur: mssql_python.Cursor, item_name: str, done: bool):
    cur.execute("INSERT INTO items VALUES (:item, :done)", {
        "item": item_name,
        "done": done
    })

with mssql_python.connect(connection_string) as conn:
    with conn.cursor() as cur:
        insert_item_named_args(cur, "play games", True)
        cur.commit() # сохраняем данные в таблицу
        cur.execute("select * from items")
        for row in cur:
            print(row)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 13
#      11 with mssql_python.connect(connection_string) as conn:
#      12     with conn.cursor() as cur:
# ---> 13         insert_item_named_args(cur, "play games", True)
#      14         cur.commit() # сохраняем данные в таблицу
#      15         cur.execute("select * from items")
#
# Cell In[30], line 6, in insert_item_named_args(cur, item_name, done)
#       5 def insert_item_named_args(cur: mssql_python.Cursor, item_name: str, done: bool):
# ----> 6     cur.execute("INSERT INTO items VALUES (:item, :done)", {
#       7         "item": item_name,
#       8         "done": done
#       9     })
#
# File ~/Projects/python-yarsu/lesson5/.venv/lib/python3.13/site-packages/mssql_python/cursor.py:942, in Cursor.execute(self, operation, use_prepare, reset_cursor, *parameters)
#     940 if parameters:
#     941     for i, param in enumerate(parameters):
# --> 942         paraminfo = self._create_parameter_types_list(
#     943             param, param_info, parameters, i
#     944         )
#     945         parameters_type.append(paraminfo)
#     947 # TODO: Use a more sophisticated string compare that handles redundant spaces etc.
#     948 #       Also consider storing last query's hash instead of full query string. This will help
#     949 #       in low-memory conditions
#     950 #       (Ex: huge number of parallel queries with huge query string sizes)
#
# File ~/Projects/python-yarsu/lesson5/.venv/lib/python3.13/site-packages/mssql_python/cursor.py:665, in Cursor._create_parameter_types_list(self, parameter, param_info, parameters_list, i, min_val, max_val)
#     661         decimal_digits = min(max(0, decimal_digits), column_size)
#     663 else:
#     664     # Fall back to automatic type inference
# --> 665     sql_type, c_type, column_size, decimal_digits, is_dae = self._map_sql_type(
#     666         parameter, parameters_list, i, min_val=min_val, max_val=max_val
#     667     )
#     669 paraminfo.paramCType = c_type
#     670 paraminfo.paramSQLType = sql_type
#
# File ~/Projects/python-yarsu/lesson5/.venv/lib/python3.13/site-packages/mssql_python/cursor.py:463, in Cursor._map_sql_type(self, param, parameters_list, i, min_val, max_val)
#     454     return (
#     455         ddbc_sql_const.SQL_TIME.value,
#     456         ddbc_sql_const.SQL_C_TYPE_TIME.value,
#    (...)    459         False,
#     460     )
#     462 # For safety: unknown/unhandled Python types should not silently go to SQL
# --> 463 raise TypeError("Unsupported parameter type: The driver cannot safely convert it to a SQL type.")
#
# TypeError: Unsupported parameter type: The driver cannot safely convert it to a SQL type.

# %% [markdown]
# Что делать если хотим вставить произвольное количество строк в таблицу?

# %%
# Передача множества параметров
def insert_item_named_args(cur: mssql_python.Cursor, items: list[tuple[str, bool]]):
    cur.executemany("INSERT INTO items VALUES (?, ?)", items)

with mssql_python.connect(connection_string) as conn:
    with conn.cursor() as cur:
        insert_item_named_args(cur, [("play games", True), ("make dinner", False)])
        cur.commit() # сохраняем данные в таблицу
        cur.execute("select * from items")
        for row in cur:
            print(row)
# Out:
# ("xxx', 1); drop table items; --", True)
# ('watch tv', True)
# ('play videogames', True)
# ('watch tv', True)
# ('play games', True)
# ('make dinner', False)

# %% [markdown]
# # Транзакции
#
# Транзакция - это последовательность операций, которая может выполниться полностью, либо не выполниться вообще. При создании подключения и курсора создается новая транзакция в рамках которой выполняются операции над БД. После этого транзакцию можно либо применить (`commit`), либо откатить (`rollback`). Если закрыть подключение без применения транзакции, то все выполненные изменения откатятся.

# %%
# Напишем код с коммитом транзакции

def insert_item_named_args(cur: mssql_python.Cursor, items: list[tuple[str, bool]]):
    raise EOFError()
    cur.executemany("INSERT INTO items VALUES (?, ?)", items)

with mssql_python.connect(connection_string) as conn:
    with conn.cursor() as cur:
        try:
            insert_item_named_args(cur, [("play games", True), ("make dinner", False)])
            conn.commit()
        except:
            conn.rollback()

# %%
import mssql_python

connection_string = 'SERVER=localhost;PORT=1433;DATABASE=todo;UID=sa;PWD=1234qwE?;Encrypt=no'
conn = mssql_python.connect(connection_string)
cur = conn.cursor()

cur.execute('SELECT * from items')

print(cur.fetchall())

cur.close()
conn.close()
# Out:
# [("xxx', 1); drop table items; --", True), ('watch tv', True), ('play videogames', True), ('watch tv', True), ('play games', True), ('make dinner', False), ('play games', True), ('make dinner', False)]

# %% [markdown]
# # Как не забывать закрыть подключение

# %%
# Перепишем код на менеджеры контекста with
